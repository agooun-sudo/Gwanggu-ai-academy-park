# %%
import numpy as np

arr = np.random.randint(10,size=(3,4,5),dtype='int8')
arr
print(arr.ndim) # 차원확인
print(arr.shape) # 크기확인
print(arr.size) # 요소의 갯수 확인
print(arr.dtype) # 데이터 타입 확인

# lst = [1, 2, 3, 4, 5]

# result = []

# for i in lst:
#     result.append(i * 10)
#-------------------------------------------------------------------------
# print(result)

# arr = np.array(lst) # 브로드캐스팅 넘파이를 쓰는 이유중 하나
# print(arr * 10)
# Out:
# 3
# (3, 4, 5)
# 60
# int8

# %%
import numpy as np

arr = np.random.randint(10,size=(3,4,5),dtype='int8')
arr
# Out:
# array([[[0, 2, 9, 3, 5],
#         [7, 1, 0, 0, 1],
#         [5, 1, 8, 0, 2],
#         [1, 5, 9, 6, 1]],
#
#        [[2, 6, 5, 2, 8],
#         [4, 8, 1, 5, 8],
#         [5, 1, 0, 0, 5],
#         [9, 3, 6, 0, 8]],
#
#        [[6, 5, 6, 7, 2],
#         [1, 3, 9, 2, 9],
#         [4, 1, 2, 7, 5],
#         [2, 4, 1, 5, 6]]], dtype=int8)
