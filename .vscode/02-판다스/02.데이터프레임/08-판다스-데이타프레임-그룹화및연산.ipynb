# %%
import pandas as pd
import numpy as np

data = {
    '이름' : ['유재석', '박명수', '정준하', '노홍철', '정형돈', '하하'],
    '지역' : ['서울', '부산', '부산', '서울', '서울', '서울'],
    '나이' : [19, 23, 20, 25, 18, 21],
    '국어점수' : [86, 90, 80, 65, 50, 60],
    '수학점수' : [86, 100, 66, 70, 40, 80],
    '코딩' : ['Python', 'Java', np.nan, 'Javascript', 'PYTHON', np.nan],
    '전공' : ['문과', '이과', '이과', '이과', '문과', '문과']
}
df = pd.DataFrame(data=data,index=['1번','2번','3번','4번','5번','6번'])
print(df)
# df.info()
# Out:
#      이름  지역  나이  국어점수  수학점수          코딩  전공
# 1번  유재석  서울  19    86    86      Python  문과
# 2번  박명수  부산  23    90   100        Java  이과
# 3번  정준하  부산  20    80    66         NaN  이과
# 4번  노홍철  서울  25    65    70  Javascript  이과
# 5번  정형돈  서울  18    50    40      PYTHON  문과
# 6번   하하  서울  21    60    80         NaN  문과

# %%
#df.groupby // numeric_only=True 그룹화후 연산
print(df.groupby("지역").mean(numeric_only=True))
print(df.groupby("지역")[["국어점수"]].mean(numeric_only=True))
# sql groupby
# Out:
#        나이   국어점수  수학점수
# 지역
# 부산  21.50  85.00  83.0
# 서울  20.75  65.25  69.0
#      국어점수
# 지역
# 부산  85.00
# 서울  65.25

# %%
print(df.groupby(["지역","전공"]).mean(numeric_only=True))
# 지역 먼저 그룹화 > 서울, 부산 이후 전공그룹화 이후 평균 점수 젤밑에는 나머지값
# Out:
#               나이       국어점수       수학점수
# 지역 전공
# 부산 이과  21.500000  85.000000  83.000000
# 서울 문과  19.333333  65.333333  68.666667
#    이과  25.000000  65.000000  70.000000

# %%
print(df.groupby(["지역","전공"]).mean(numeric_only=True).sort_values("국어점수"))
# Out:
#               나이       국어점수       수학점수
# 지역 전공
# 서울 이과  25.000000  65.000000  70.000000
#    문과  19.333333  65.333333  68.666667
# 부산 이과  21.500000  85.000000  83.000000

# %%
# 그룹함수는 반드시 아래의 함수만 같이 쓸수 있으며,
# 집계함수라 한다.
# sum()    합계
# mean()    평균
# median()    중앙값
# max()    최대값
# min()    최소값
# count()    값의 개수 (NaN 제외)
# size()    그룹별 전체 원소 수 (NaN 포함)
# std()    표준편차
# var()    분산
# first()    첫 번째 값
# last()    마지막 값
# nunique()    고유값 개수
# agg()    여러 집계 함수를 한 번에 적용할 때 사용
# 코딩  이름
# 지역
# 부산   1   2
# 서울   3   4
print(df.groupby("지역")[['코딩',"이름"]].count()) # 널체크용으로 쓰임
# Out:
#     코딩  이름
# 지역
# 부산   1   2
# 서울   3   4
